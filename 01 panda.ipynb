# %%
import pandas as pd

# %%
data=pd.read_csv("Loan_data.csv")

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
# difference ways to access the rows and columns in your dataset using pandas

type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (614, 13)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
custid=data['Loan_ID']

# %%
sal=data[['ApplicantIncome','CoapplicantIncome']]

# %%
type(sal)
# Out:
# pandas.core.frame.DataFrame

# %%
type(custid)
# Out:
# pandas.core.series.Series

# %%
custid=pd.DataFrame(custid)

# %%
type(custid)
# Out:
# pandas.core.frame.DataFrame

# %%
custid1=data.iloc[:,0]

# %%
custid1.head(2)
# Out:
# 0    LP001002
# 1    LP001003
# Name: Loan_ID, dtype: object

# %%
custid.head(2)
# Out:
#     Loan_ID
# 0  LP001002
# 1  LP001003

# %%
col1=data.iloc[:,0:4]

# %%
col1.head(2)
# Out:
#     Loan_ID Gender Married Dependents
# 0  LP001002   Male      No          0
# 1  LP001003   Male     Yes          1

# %% [markdown]
# # Display the first 10 rows of 5th column

# %%
col2=data.iloc[0:10,4]

# %%
col2
# Out:
# 0        Graduate
# 1        Graduate
# 2        Graduate
# 3    Not Graduate
# 4        Graduate
# 5        Graduate
# 6    Not Graduate
# 7        Graduate
# 8        Graduate
# 9        Graduate
# Name: Education, dtype: object

# %%
col2.shape
# Out:
# (10,)

# %%
col1=pd.DataFrame(col2)

# %%
col1.shape
# Out:
# (10, 1)

# %%
data.iloc[0:10,[0,4,6]]
# Out:
#     Loan_ID     Education  ApplicantIncome
# 0  LP001002      Graduate             5849
# 1  LP001003      Graduate             4583
# 2  LP001005      Graduate             3000
# 3  LP001006  Not Graduate             2583
# 4  LP001008      Graduate             6000
# 5  LP001011      Graduate             5417
# 6  LP001013  Not Graduate             2333
# 7  LP001014      Graduate             3036
# 8  LP001018      Graduate             4006
# 9  LP001020      Graduate            12841

# %%
data.iloc[:10,:8]
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome
# 0             5849                0.0
# 1             4583             1508.0
# 2             3000                0.0
# 3             2583             2358.0
# 4             6000                0.0
# ...

# %%
data.iloc[:10,-3:]
# Out:
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# 7             0.0     Semiurban           N
# 8             1.0         Urban           Y
# 9             1.0     Semiurban           N

# %% [markdown]
# #Create a new column for loan repay in terms of years and concatenate with new data

# %%
der_col=data['Loan_Amount_Term']/12

# %%
der_col.shape
# Out:
# (614,)

# %%
data['Term_Year']=data['Term_Year']*12

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN              30.0
# 1             4583             1508.0       128.0              30.0
# 2             3000                0.0        66.0              30.0
# 3             2583             2358.0       120.0              30.0
# 4             6000                0.0       141.0              30.0
#
#    Credit_History Property_Area Loan_Status  Term_Year
# 0             1.0         Urban           Y       30.0
# ...

# %%
data.drop('Term_Year',axis=1,inplace=True)

# %%
data.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN              30.0
# 1             4583             1508.0       128.0              30.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %% [markdown]
# # Count how many males and females are there in this dataset

# %%
gen_count=data['Gender'].value_counts()

# %%
gen_count
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gen_count.plot(kind='pie')

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
data['Gender'].nunique()
# Out:
# 2

# %%
data_male=data[data['Gender']=='Male']

# %%
data_male
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# 6    LP001013   Male     Yes          0  Not Graduate            No
# 7    LP001014   Male     Yes         3+      Graduate            No
# 8    LP001018   Male     Yes          2      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 10   LP001024   Male     Yes          2      Graduate            No
# 11   LP001027   Male     Yes          2      Graduate           NaN
# 12   LP001028   Male     Yes          2      Graduate            No
# ...

# %%
len(data_male)
# Out:
# 489

# %%
meandata=data_male['ApplicantIncome'].mean()

# %%
data['ApplicantIncome'].mean()
# Out:
# 5403.459283387622

# %%
Avincfemale=(data['ApplicantIncome'].sum()-data_male['ApplicantIncome'].sum())

# %%
Avincfemale
# Out:
# 654405

# %%
Avincfemale=Avincfemale/112

# %%
Avincfemale
# Out:
# 5842.901785714285

# %%
data_female=data[data['Gender']=='Female']
meanfemale=data_female['ApplicantIncome'].mean()

# %%
meandata
# Out:
# 5446.460122699386

# %%
m1=data_male[data_male['ApplicantIncome']>meandata]

# %%
len(m1)
# Out:
# 148

# %%
m1['Gender'].value_counts()
# Out:
# Male    148
# Name: Gender, dtype: int64

# %%
m2=data_female[data_female['ApplicantIncome']>meanfemale]

# %%
len(m2)
# Out:
# 27

# %%
len(data_male)
# Out:
# 489

# %%
len(m1)/len(data_male)*100
# Out:
# 30.265848670756647

# %%
len(m2)/len(data_female)*100
# Out:
# 24.107142857142858

# %%
gen_sal=data.groupby('Gender')['ApplicantIncome'].mean()

# %%
gen_sal
# Out:
# Gender
# Female    4643.473214
# Male      5446.460123
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby('Gender')['ApplicantIncome'].max()
# Out:
# Gender
# Female    19484
# Male      81000
# Name: ApplicantIncome, dtype: int64

# %%
gen_inc=data.groupby('Gender').agg({'ApplicantIncome':['mean','max','min','sum'], 'LoanAmount':['mean','max','min']})

# %%
gen_inc
# Out:
#        ApplicantIncome                       LoanAmount
#                   mean    max  min      sum        mean    max   min
# Gender
# Female     4643.473214  19484  210   520069  126.697248  600.0   9.0
# Male       5446.460123  81000  150  2663319  149.265957  650.0  17.0

# %%
data.groupby(['Gender','Education'])['ApplicantIncome'].mean()
# Out:
# Gender  Education
# Female  Graduate        4646.467391
#         Not Graduate    4629.700000
# Male    Graduate        5992.345745
#         Not Graduate    3630.061947
# Name: ApplicantIncome, dtype: float64

# %%
data.groupby(['Gender','Education'])['ApplicantIncome'].mean().unstack()
# Out:
# Education     Graduate  Not Graduate
# Gender
# Female     4646.467391   4629.700000
# Male       5992.345745   3630.061947

# %%
data.pivot_table(index='Gender', columns='Education' ,values = 'ApplicantIncome')
# Out:
# Education     Graduate  Not Graduate
# Gender
# Female     4646.467391   4629.700000
# Male       5992.345745   3630.061947

# %%
import numpy as np
data.pivot_table(index='Gender', columns='Education' ,values = 'ApplicantIncome', aggfunc=[np.sum])
# Out:
#                sum
# Education Graduate Not Graduate
# Gender
# Female      427475        92594
# Male       2253122       410197

# %%
pivotsuper=data.pivot_table(index=['Gender','Education'], columns=['Married', 'Property_Area'], values=['ApplicantIncome', 'LoanAmount']
                 , aggfunc={'ApplicantIncome':['mean'],'LoanAmount':['sum']})

# %%
pivotsuper
# Out:
#                     ApplicantIncome                                         \
#                                mean
# Married                          No                                    Yes
# Property_Area                 Rural    Semiurban        Urban        Rural
# Gender Education
# Female Graduate         4266.933333  4784.750000  3838.173913  4888.666667
#        Not Graduate     3642.250000  5809.500000  6155.500000  5621.000000
# Male   Graduate         5788.225806  5973.090909  5394.857143  6610.848101
#        Not Graduate     4196.538462  3766.909091  2763.000000  3683.500000
#
#                                               LoanAmount                    \
#                                                      sum
# Married                                               No
# Property_Area          Semiurban        Urban      Rural Semiurban   Urban
# Gender Education
# Female Graduate      4819.937500  6564.666667     1970.0    3204.0  2500.0
# ...
