# %%
import pandas as pd

# %%
data=pd.read_csv("Loan_data.csv")

# %%
data.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data.isnull().sum()/data.count()*100
# Out:
# Loan_ID              0.000000
# Gender               2.163062
# Married              0.490998
# Dependents           2.504174
# Education            0.000000
# Self_Employed        5.498282
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.716216
# Loan_Amount_Term     2.333333
# Credit_History       8.865248
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
data.isnull().sum()/len(data)*100
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
data_drop=data.dropna()

# %%
len(data_drop)
# Out:
# 480

# %%
1-len(data_drop)/len(data)
# Out:
# 0.21824104234527686

# %%
data_drop1=data.dropna(thresh=12)
len(data_drop1)
# Out:
# 601

# %%
data_drop1.isnull().sum()/len(data_drop1)*100
# Out:
# Loan_ID              0.000000
# Gender               1.996672
# Married              0.000000
# Dependents           1.663894
# Education            0.000000
# Self_Employed        4.159734
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.161398
# Loan_Amount_Term     1.996672
# Credit_History       7.154742
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %%
data_fill=data.fillna(method='bfill')

# %%
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data_fill.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data_fillf=data.fillna(method='ffill')

# %%
data_fillf.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
data['Credit_History']=data['Credit_History'].fillna(0)

# %%
data.head(30)
# Out:
#      Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0   LP001002    Male      No          0      Graduate            No
# 1   LP001003    Male     Yes          1      Graduate            No
# 2   LP001005    Male     Yes          0      Graduate           Yes
# 3   LP001006    Male     Yes          0  Not Graduate            No
# 4   LP001008    Male      No          0      Graduate            No
# 5   LP001011    Male     Yes          2      Graduate           Yes
# 6   LP001013    Male     Yes          0  Not Graduate            No
# 7   LP001014    Male     Yes         3+      Graduate            No
# 8   LP001018    Male     Yes          2      Graduate            No
# 9   LP001020    Male     Yes          1      Graduate            No
# 10  LP001024    Male     Yes          2      Graduate            No
# 11  LP001027    Male     Yes          2      Graduate           NaN
# 12  LP001028    Male     Yes          2      Graduate            No
# ...

# %%
data['ApplicantIncome']=data['ApplicantIncome'].fillna(data['ApplicantIncome'].mean())

# %%
data['Gender']=data['Gender'].fillna(data['Gender'].mode())

# %%
data1=pd.read_csv("Loan_data.csv")

# %%
data1['ApplicantIncome']=data1[data1['Gender']=='Male']['ApplicantIncome'].mean()

# %%
data2=pd.read_csv("Loan_data.csv")

# %%
data2['ApplicantIncome']=data2['ApplicantIncome'][data2['Gender']=='Male'].fillna(data2[data2['Gender']=='Male']['ApplicantIncome'].mean())
data2['ApplicantIncome'][data2['Gender']=='Female'].fillna(data2[data2['Gender']=='Female']['ApplicantIncome'].mean())
# Out:
# 17    NaN
# 29    NaN
# 37    NaN
# 45    NaN
# 48    NaN
# 49    NaN
# 50    NaN
# 51    NaN
# 52    NaN
# 54    NaN
# 64    NaN
# 69    NaN
# 80    NaN
# 82    NaN
# 96    NaN
# 111   NaN
# 113   NaN
# 116   NaN
# 119   NaN
# 121   NaN
# 122   NaN
# 125   NaN
# 136   NaN
# 145   NaN
# 146   NaN
# 148   NaN
# 166   NaN
# 184   NaN
# 197   NaN
# 198   NaN
#        ..
# 430   NaN
# 435   NaN
# 439   NaN
# 463   NaN
# 468   NaN
# 473   NaN
# 480   NaN
# 493   NaN
# 495   NaN
# 500   NaN
# 501   NaN
# 509   NaN
# 516   NaN
# 519   NaN
# 534   NaN
# 540   NaN
# 541   NaN
# 542   NaN
# 544   NaN
# 548   NaN
# 556   NaN
# 559   NaN
# 561   NaN
# 568   NaN
# 582   NaN
# 587   NaN
# 600   NaN
# 604   NaN
# 609   NaN
# 613   NaN
# Name: ApplicantIncome, Length: 112, dtype: float64

# %%
data2['ApplicantIncome']
# Out:
# 0       5849.0
# 1       4583.0
# 2       3000.0
# 3       2583.0
# 4       6000.0
# 5       5417.0
# 6       2333.0
# 7       3036.0
# 8       4006.0
# 9      12841.0
# 10      3200.0
# 11      2500.0
# 12      3073.0
# 13      1853.0
# 14      1299.0
# 15      4950.0
# 16      3596.0
# 17         NaN
# 18      4887.0
# 19      2600.0
# 20      7660.0
# 21      5955.0
# 22      2600.0
# 23         NaN
# 24      3717.0
# 25      9560.0
# 26      2799.0
# 27      4226.0
# 28      1442.0
# 29         NaN
#         ...
# 584     2787.0
# 585     4283.0
# 586     2297.0
# 587        NaN
# 588        NaN
# 589     2726.0
# 590     3000.0
# 591     6000.0
# 592        NaN
# 593     3859.0
# 594    16120.0
# 595     3833.0
# 596     6383.0
# 597     2987.0
# 598     9963.0
# 599     5780.0
# 600        NaN
# 601     2894.0
# 602     5703.0
# 603     3676.0
# 604        NaN
# 605     2400.0
# 606     3400.0
# 607     3987.0
# 608     3232.0
# 609        NaN
# 610     4106.0
# 611     8072.0
# ...

# %%
data3=pd.read_csv("Loan_data.csv")

# %%
data_male=data2[data2['Gender']=='Male']

# %%
data3.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data_male['LoanAmount']=data_male['LoanAmount'].fillna(data_male['LoanAmount'].mean())
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_female=data2[data2['Gender']=='Female']

# %%
data_female['LoanAmount']=data_female['LoanAmount'].fillna(data_female['LoanAmount'].mean())
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data_male.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               2
# Dependents           12
# Education             0
# Self_Employed        24
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       38
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
data_mer=pd.concat([data_male,data_female])

# %%
data_mer.isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# ApplicantIncome      112
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term      14
# Credit_History        49
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
data2=data_mer

# %%
data2.isnull().sum()
# Out:
# Loan_ID                0
# Gender                 0
# Married                3
# Dependents            15
# Education              0
# Self_Employed         32
# ApplicantIncome      112
# CoapplicantIncome      0
# LoanAmount             0
# Loan_Amount_Term      14
# Credit_History        49
# Property_Area          0
# Loan_Status            0
# dtype: int64

# %%
# !pip install missingpy

# %%
data3['LoanAmount']=data['LoanAmount'].fillna(data.groupby('Gender')['LoanAmount'].transform('mean'))

# %%
data3.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import pandas as pd
from missingpy import KNNImputer

# %%
data=pd.read_csv('Loan_Data.csv')
data_num=data._get_numeric_data()

# %%
data_num.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
imputer=KNNImputer()
data_num1=imputer.fit_transform(data_num)

# %%
data_num1
# Out:
# array([[5.849e+03, 0.000e+00, 1.478e+02, 3.600e+02, 1.000e+00],
#        [4.583e+03, 1.508e+03, 1.280e+02, 3.600e+02, 1.000e+00],
#        [3.000e+03, 0.000e+00, 6.600e+01, 3.600e+02, 1.000e+00],
#        ...,
#        [8.072e+03, 2.400e+02, 2.530e+02, 3.600e+02, 1.000e+00],
#        [7.583e+03, 0.000e+00, 1.870e+02, 3.600e+02, 1.000e+00],
#        [4.583e+03, 0.000e+00, 1.330e+02, 3.600e+02, 0.000e+00]])

# %%
data_num1=pd.DataFrame(data_num1)

# %%
data_num1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0       147.8             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
#data_num1=data_num1.rename(columns={0:col[0],1:col[1],2:col[2],3:col[3],4:col[4]})
data_num1.columns=data_num.columns

# %%
data_num1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           5849.0                0.0       147.8             360.0
# 1           4583.0             1508.0       128.0             360.0
# 2           3000.0                0.0        66.0             360.0
# 3           2583.0             2358.0       120.0             360.0
# 4           6000.0                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
data_num1.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %%
data1=pd.read_csv('Loan_Data.csv')
data_num1=data1._get_numeric_data()

# %%
data_num1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
imputer1=KNNImputer()
data_num2=imputer.fit_transform(data_num1)

# %%
data_num2
# Out:
# array([[5.849e+03, 0.000e+00, 1.478e+02, 3.600e+02, 1.000e+00],
#        [4.583e+03, 1.508e+03, 1.280e+02, 3.600e+02, 1.000e+00],
#        [3.000e+03, 0.000e+00, 6.600e+01, 3.600e+02, 1.000e+00],
#        ...,
#        [8.072e+03, 2.400e+02, 2.530e+02, 3.600e+02, 1.000e+00],
#        [7.583e+03, 0.000e+00, 1.870e+02, 3.600e+02, 1.000e+00],
#        [4.583e+03, 0.000e+00, 1.330e+02, 3.600e+02, 0.000e+00]])

# %%
from missingpy import MissForest
data=pd.read_csv('Loan_Data.csv')
data1=data._get_numeric_data()

# %%
imputer=MissForest()
data_imputed1=imputer.fit_transform(data1)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2

# %%
data_imputed1=pd.DataFrame(data_imputed1)

# %%
data_imputed2=imputer.fit_transform(data_imputed1)
# Out:
# D:\Anaconda3\lib\site-packages\missingpy\missforest.py:528: UserWarning: No missing value located; returning original dataset.
#   warnings.warn("No missing value located; returning original "

# %%
data_imputed2
# Out:
# array([[5.84900000e+03, 0.00000000e+00, 1.39843333e+02, 3.60000000e+02,
#         1.00000000e+00],
#        [4.58300000e+03, 1.50800000e+03, 1.28000000e+02, 3.60000000e+02,
#         1.00000000e+00],
#        [3.00000000e+03, 0.00000000e+00, 6.60000000e+01, 3.60000000e+02,
#         1.00000000e+00],
#        ...,
#        [8.07200000e+03, 2.40000000e+02, 2.53000000e+02, 3.60000000e+02,
#         1.00000000e+00],
#        [7.58300000e+03, 0.00000000e+00, 1.87000000e+02, 3.60000000e+02,
#         1.00000000e+00],
#        [4.58300000e+03, 0.00000000e+00, 1.33000000e+02, 3.60000000e+02,
#         0.00000000e+00]])
